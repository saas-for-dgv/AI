# %% [markdown]
# <a href="https://colab.research.google.com/github/saas-for-dgv/AI/blob/main/2_tensors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
# Importing the PyTorch library
import torch
# Importing the NumPy library
import numpy as np

# Importing the matplotlib.pyplot function
import matplotlib.pyplot as plt

# Applying the logspace function to get a tensor of size 15 with values from -5 to 5 using base 2
#a = torch.logspace(start=1, end=27,steps=3)
a = torch.logspace(.5,1,10)
print(a)

# Plotting
plt.plot(a.numpy(), np.zeros(a.numpy().shape), color = 'red', marker = "o")
plt.title("torch.linspace")
plt.xlabel("X")
plt.ylabel("Y")

plt.show()
# Out:
# tensor([ 3.1623,  3.5938,  4.0842,  4.6416,  5.2750,  5.9948,  6.8129,  7.7426,
#          8.7992, 10.0000])
